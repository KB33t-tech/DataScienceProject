# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
data = pd.read_csv('../Raw_data/15min_sam.csv')

# %%
x = data['gFx']
y = data['gFy']
z = data['gFz']
total = data['TgF']

# %%
# plt.subplot(1,3)
# plt.plot(x)
# plt.subplot(2,3)
# plt.plot(y)
# plt.subplot(3,3)
# plt.plot(z)
# plt.show()


# plt.figure()
plt.plot(x)
# plt.figure()
# plt.plot(y)
# plt.figure()
# plt.plot(z)
# plt.show()

# %%
plt.plot(y)

# %%
plt.plot(z)

# %%
b,a = signal.butter(3,0.01,btype = 'lowpass',analog = False)
low_pass_x = signal.filtfilt(b,a,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-2c4739b0c19c> in <module>
# ----> 1 b,a = signal.butter(3,0.01,btype = 'lowpass',analog = False)
#       2 low_pass_x = signal.filtfilt(b,a,x)
#
# NameError: name 'signal' is not defined
